# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\pc\\Documents\\Python_2019\house_data.csv')
df.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
correlations = df.corr()
sns.heatmap(correlations,square = True, cmap = "YlGnBu")
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
corr = round(df.corr(method='pearson'), 2)
corr[ corr.iloc[:, :] > 0.6]
# Out:
#                 id  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id             1.0    NaN       NaN        NaN          NaN       NaN     NaN
# price          NaN   1.00       NaN        NaN         0.70       NaN     NaN
# bedrooms       NaN    NaN       1.0        NaN          NaN       NaN     NaN
# bathrooms      NaN    NaN       NaN       1.00         0.75       NaN     NaN
# sqft_living    NaN   0.70       NaN       0.75         1.00       NaN     NaN
# sqft_lot       NaN    NaN       NaN        NaN          NaN      1.00     NaN
# floors         NaN    NaN       NaN        NaN          NaN       NaN     1.0
# waterfront     NaN    NaN       NaN        NaN          NaN       NaN     NaN
# view           NaN    NaN       NaN        NaN          NaN       NaN     NaN
# condition      NaN    NaN       NaN        NaN          NaN       NaN     NaN
# grade          NaN   0.67       NaN       0.66         0.76       NaN     NaN
# ...

# %%
from pylab import rcParams
import scipy
from scipy.stats.stats import pearsonr

# %matplotlib inline
rcParams['figure.figsize'] = 8, 4
plt.style.use('seaborn-whitegrid')

# %%
pair_plot = df[['bedrooms', 'sqft_living', 'price','grade']]             #show pair-plot result  (scatter plot)
sns.pairplot(pair_plot)

# %%
sum = df.groupby(by='grade').sum()
mean = df.groupby(by='grade').mean()
count = df.groupby(by='grade').count()

# %%
plt.title('Mean Price by Grade')
plt.xlabel('Grade') 
plt.ylabel('Mean Price')
plt.bar(mean.index, mean.price)
plt.grid()
plt.show()

# %%
df2 = df.groupby(by='zipcode').mean()

plt.figure(figsize=(14,30))
df2['price'].sort_values().plot(kind='barh', grid=True)
plt.title('House Price by Zipcode')
plt.xlabel('Mean Price')
plt.ylabel('Zipcode') 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(df.sqft_living, df.price)
slope, intercept = np.polyfit(df.sqft_living, df.price, 1)
plt.plot(df.sqft_living, df.sqft_living * slope + intercept, "r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(df2.sqft_living, df2.price)
slope, intercept = np.polyfit(df2.sqft_living, df2.price, 1)
plt.plot(df2.sqft_living, df2.sqft_living * slope + intercept, "r")
plt.show()

# %%
df2['offset'] = df2['price'] - (df2.sqft_living*slope + intercept)
df2['offset2'] = np.abs(df2['price'] - (df2.sqft_living*slope + intercept))
df2_sort = df2.sort_values(by = 'offset2', ascending=False)
df2_sort.head()
# Out:
#                    id         price  bedrooms  bathrooms  sqft_living  \
# zipcode
# 98039    3.755708e+09  2.160607e+06  4.060000   3.200000  3800.900000
# 98004    4.394237e+09  1.355927e+06  3.854890   2.527603  2909.022082
# 98109    3.458919e+09  8.796236e+05  3.192661   2.158257  2054.779817
# 98119    4.303215e+09  8.494480e+05  3.260870   2.224185  2005.614130
# 98112    4.826282e+09  1.095499e+06  3.509294   2.373606  2498.743494
#
#              sqft_lot    floors  waterfront      view  condition  ...  \
# zipcode                                                           ...
# 98039    17403.560000  1.560000    0.020000  0.440000   3.480000  ...
# 98004    13104.220820  1.432177    0.003155  0.305994   3.495268  ...
# 98109     3621.082569  1.729358    0.000000  0.477064   3.477064  ...
# 98119     3615.217391  1.793478    0.000000  0.548913   3.375000  ...
# 98112     4990.431227  1.806691    0.000000  0.148699   3.516729  ...
#
# ...

# %%
df2['offset'][65:70], df2['offset2'][65:70]
# Out:
# (zipcode
#  98177     -4591.774867
#  98178    -53733.538264
#  98188   -114381.316287
#  98198    -69996.155761
#  98199    197097.959382
#  Name: offset, dtype: float64, zipcode
#  98177      4591.774867
#  98178     53733.538264
#  98188    114381.316287
#  98198     69996.155761
#  98199    197097.959382
#  Name: offset2, dtype: float64)

# %%
df2.to_csv(r'C:\\Users\\pc\\Documents\\Python_2019\test.csv', header=True)
