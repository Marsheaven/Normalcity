# %%
pwd
# Out:
# 'C:\\Users\\haha pc\\Documents'

# %%
import pandas as pd

# %%
df = pd.read_csv('house_data.csv')

# %%
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
df.sort_values(by='price')
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1149   3421079032  20150217T000000    75000.0         1       0.00
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 2141   1623049041  20140508T000000    82500.0         2       1.00
# 18468  7999600180  20140529T000000    83000.0         2       1.00
# 3767   1523049188  20150430T000000    84000.0         2       1.00
# 16714  1322049150  20150305T000000    85000.0         2       1.00
# 10253  2422049104  20140915T000000    85000.0         2       1.00
# 13756  1788900230  20140722T000000    86500.0         3       1.00
# 5866   9320900420  20141014T000000    89000.0         3       1.00
# 3108   1721801591  20150219T000000    89950.0         1       1.00
# ...

# %%
df.sort_values(by=['price','bathrooms'])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1149   3421079032  20150217T000000    75000.0         1       0.00
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 2141   1623049041  20140508T000000    82500.0         2       1.00
# 18468  7999600180  20140529T000000    83000.0         2       1.00
# 3767   1523049188  20150430T000000    84000.0         2       1.00
# 10253  2422049104  20140915T000000    85000.0         2       1.00
# 16714  1322049150  20150305T000000    85000.0         2       1.00
# 13756  1788900230  20140722T000000    86500.0         3       1.00
# 5866   9320900420  20141014T000000    89000.0         3       1.00
# 3108   1721801591  20150219T000000    89950.0         1       1.00
# ...

# %%
df.sort_values(by=['price','bathrooms'], ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 8092   1924059029  20140617T000000  4668000.0         5       6.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 8638   3835500195  20140618T000000  4489000.0         4       3.00
# 12370  6065300370  20150506T000000  4208000.0         5       6.00
# 4149   6447300265  20141014T000000  4000000.0         4       5.50
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# ...

# %%
df[(df['bathrooms']==2)&(df['price']<150000)].sort_values(by='price', ascending=False)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 15144  1823049182  20140915T000000  147400.0         3        2.0
# 15810  7129304540  20141220T000000  133000.0         5        2.0
# 12208  4031000520  20140708T000000  115000.0         1        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 15144         1080      9225     1.0           0     0     ...          7
# 15810         1430      5600     1.5           0     0     ...          6
# 12208         1150      9812     1.0           0     0     ...          7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15144        1080              0      1955             0    98146  47.4842
# 15810        1430              0      1947             0    98118  47.5192
# 12208        1150              0      1962             0    98001  47.2951
#
#           long  sqft_living15  sqft_lot15
# 15144 -122.346           1410        9840
# ...

# %%
df[(df['bathrooms']==2)&(df['price']<200000)].sort_values(by='price', ascending=False)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 10916  7227800055  20140909T000000  199500.0         4        2.0
# 14719  7227800065  20141016T000000  199000.0         4        2.0
# 2769   3352401981  20140521T000000  199000.0         4        2.0
# 12241  7682200320  20150409T000000  197400.0         3        2.0
# 6958   3279000460  20140926T000000  196500.0         3        2.0
# 1691   3356406510  20140530T000000  196440.0         3        2.0
# 2877   2781270090  20150225T000000  195000.0         2        2.0
# 11481  6083000071  20141110T000000  195000.0         3        2.0
# 14601  2501600150  20150310T000000  194000.0         4        2.0
# 16667  7153400010  20140812T000000  190500.0         3        2.0
# 1928   3972900160  20150403T000000  190000.0         4        2.0
# 19155  7227800040  20140604T000000  190000.0         5        2.0
# 3244   1545805490  20141006T000000  190000.0         3        2.0
# ...

# %%
df[11:20]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 11  9212900260  20140527T000000  468000.0         2       1.00         1160
# 12   114101516  20140528T000000  310000.0         3       1.00         1430
# 13  6054650070  20141007T000000  400000.0         3       1.75         1370
# 14  1175000570  20150312T000000  530000.0         5       2.00         1810
# 15  9297300055  20150124T000000  650000.0         4       3.00         2950
# 16  1875500060  20140731T000000  395000.0         3       2.00         1890
# 17  6865200140  20140529T000000  485000.0         4       1.00         1600
# 18    16000397  20141205T000000  189000.0         2       1.00         1200
# 19  7983200060  20150424T000000  230000.0         3       1.00         1250
#
#     sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 11      6000     1.0           0     0     ...          7         860
# ...

# %%
df.iloc[0:3,0:5]
# Out:
#            id             date     price  bedrooms  bathrooms
# 0  7129300520  20141013T000000  221900.0         3       1.00
# 1  6414100192  20141209T000000  538000.0         3       2.25
# 2  5631500400  20150225T000000  180000.0         2       1.00

# %%
df['bathrooms']
# Out:
# 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
# 5        4.50
# 6        2.25
# 7        1.50
# 8        1.00
# 9        2.50
# 10       2.50
# 11       1.00
# 12       1.00
# 13       1.75
# 14       2.00
# 15       3.00
# 16       2.00
# 17       1.00
# 18       1.00
# 19       1.00
# 20       1.75
# 21       2.75
# 22       2.50
# 23       1.50
# 24       2.25
# 25       2.00
# 26       1.75
# 27       1.00
# 28       1.75
# 29       2.50
#          ...
# 21583    1.00
# 21584    2.50
# 21585    2.50
# 21586    2.50
# 21587    2.50
# 21588    1.50
# 21589    2.50
# 21590    3.50
# 21591    2.75
# 21592    2.25
# 21593    3.75
# 21594    2.75
# 21595    2.25
# 21596    2.75
# 21597    3.25
# 21598    2.50
# 21599    3.00
# 21600    3.75
# 21601    2.50
# 21602    1.75
# 21603    2.50
# 21604    2.00
# 21605    2.50
# 21606    3.50
# 21607    2.50
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# ...

# %%
df [['bedrooms', 'sqft_living']]
# Out:
#        bedrooms  sqft_living
# 0             3         1180
# 1             3         2570
# 2             2          770
# 3             4         1960
# 4             3         1680
# 5             4         5420
# 6             3         1715
# 7             3         1060
# 8             3         1780
# 9             3         1890
# 10            3         3560
# 11            2         1160
# 12            3         1430
# 13            3         1370
# 14            5         1810
# 15            4         2950
# 16            3         1890
# 17            4         1600
# 18            2         1200
# 19            3         1250
# 20            4         1620
# 21            3         3050
# 22            5         2270
# 23            2         1070
# 24            3         2450
# 25            3         1710
# 26            3         2450
# 27            3         1400
# 28            3         1520
# 29            4         2570
# ...         ...          ...
# ...

# %%
df.groupby(by='bedrooms')['price'].mean().round()
# Out:
# bedrooms
# 0      409504.0
# 1      317643.0
# 2      401373.0
# 3      466232.0
# 4      635420.0
# 5      786600.0
# 6      825521.0
# 7      951185.0
# 8     1105077.0
# 9      894000.0
# 10     819333.0
# 11     520000.0
# 33     640000.0
# Name: price, dtype: float64

# %%
df.groupby(by=['bedrooms', 'bathrooms'])['price'].mean().round()
# Out:
# bedrooms  bathrooms
# 0         0.00          520371.0
#           0.75          265000.0
#           1.00          228000.0
#           1.50          288000.0
#           2.50          299983.0
# 1         0.00          279667.0
#           0.50          255000.0
#           0.75          251054.0
#           1.00          316630.0
#           1.25          881750.0
#           1.50          325746.0
#           1.75          366050.0
#           2.00          297167.0
#           2.25          436225.0
#           2.50          489500.0
# 2         0.50          191000.0
#           0.75          327514.0
#           1.00          348073.0
#           1.25          468983.0
#           1.50          410121.0
#           1.75          471249.0
#           2.00          448356.0
#           2.25          517655.0
#           2.50          540897.0
#           2.75          550942.0
#           3.00          644588.0
#           3.25          866650.0
# ...

# %%
import numpy as np

# %%
df.groupby(by='bedrooms')['price'].agg([np.sum, np.mean, np.median, np.var, np.std, np.min, np.max])
# Out:
#                    sum          mean    median           var            std  \
# bedrooms
# 0         5.323550e+06  4.095038e+05  288000.0  1.286532e+11  358682.627507
# 1         6.321093e+07  3.176429e+05  299000.0  2.216077e+10  148864.955017
# 2         1.107789e+09  4.013727e+05  374000.0  3.922453e+10  198051.827269
# 3         4.580264e+09  4.662321e+05  413000.0  6.889038e+10  262469.771863
# 4         4.372957e+09  6.354195e+05  549997.5  1.510056e+11  388594.441911
# 5         1.259346e+09  7.865998e+05  620000.0  3.554592e+11  596204.003693
# 6         2.245416e+08  8.255206e+05  650000.0  6.387827e+11  799238.819958
# 7         3.614502e+07  9.511847e+05  728580.0  5.475313e+11  739953.558961
# 8         1.436600e+07  1.105077e+06  700000.0  8.054986e+11  897495.725295
# 9         5.363999e+06  8.939998e+05  817000.0  1.455681e+11  381533.900984
# 10        2.458000e+06  8.193333e+05  660000.0  8.104133e+10  284677.595419
# ...

# %%
df.pivot_table(index='zipcode', columns='bedrooms', values='price', aggfunc=np.mean).round()
# Out:
# bedrooms         0         1          2          3          4          5   \
# zipcode
# 98001      139950.0  169333.0   217795.0   256070.0   325340.0   318516.0
# 98002           NaN  116500.0   187162.0   224579.0   261098.0   270600.0
# 98003           NaN  360000.0   215894.0   265377.0   344254.0   428175.0
# 98004           NaN       NaN   810607.0  1014349.0  1422505.0  1865356.0
# 98005           NaN       NaN   780000.0   692643.0   865821.0   880197.0
# 98006           NaN       NaN   864681.0   679875.0   923401.0  1032163.0
# 98007           NaN       NaN   454820.0   546058.0   686244.0   651174.0
# 98008           NaN       NaN   896367.0   580785.0   619291.0   849020.0
# 98010           NaN  440000.0   308650.0   366626.0   545879.0   345466.0
# 98011           NaN  310000.0   368222.0   473202.0   494498.0   595364.0
# 98014           NaN  305236.0   317262.0   421774.0   641518.0   855500.0
# ...

# %%
df['date']=pd.to_datetime(df['date'])
df.head(3)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
#
# ...

# %%
 df['sqm_living'] = df['sqft_living']/10.764
 df.head(3)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view     ...      sqft_above  sqft_basement  \
# 0      5650     1.0           0     0     ...            1180              0
# 1      7242     2.0           0     0     ...            2170            400
# 2     10000     1.0           0     0     ...             770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15  sqm_living
# 0        5650  109.624675
# 1        7639  238.758826
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
np.mean(df['price'])
# Out:
# 540088.1417665294
