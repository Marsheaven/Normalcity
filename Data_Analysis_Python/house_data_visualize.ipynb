# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as pltpl

# %%
df = pd.read_csv('house_data.csv')
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
plt.plot(df['price'], df['sqft_living'],'o')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['price'], df['sqft_living'], 'o', color='lightgray')
plt.plot(df[df['zipcode']==98002]['price'], df[df['zipcode']==98002]['sqft_living'], 'o', color='red')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['price'], df['sqft_living'], 'o', color='lightgray')
plt.plot(df[df['zipcode']==98002]['price'], df[df['zipcode']==98002]['sqft_living'], 'o', color='red')
plt.plot(df[df['zipcode']==98039]['price'], df[df['zipcode']==98039]['sqft_living'], 'o', color='limegreen')
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])
df.head(3)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view     ...      sqft_above  sqft_basement  \
# 0      5650     1.0           0     0     ...            1180              0
# 1      7242     2.0           0     0     ...            2170            400
# 2     10000     1.0           0     0     ...             770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15  sqm_living
# 0        5650  109.624675
# 1        7639  238.758826
# ...

# %%
plt.figure(figsize=(12,6))
df_group = df.groupby(by='date')['price'].sum()
plt.plot(df_group.index, df_group.values, '-')
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.hist(df['price'], bins = 100)
plt.show()

# %%
from sklearn import linear_model

model = linear_model.LinearRegression()
columns = ['bedrooms','sqft_living', 'grade', 'condition']

model.fit(df[columns], df['price'])

print('Coefficients', np.round(model.coef_, 1))
print('Interception', round(model.intercept_, 1))
print('')
for i, col in enumerate(columns):
    print(col, round(model.coef_[i], 1))
    
print('')
prediction = model.predict([[3, 3000, 10, 3]])
print('Prediction', prediction.round(1)[0])
# Out:
# Coefficients [-45678.3    212.3 100137.6  66146.3]
# Interception -739769.2
#
# bedrooms -45678.3
# sqft_living 212.3
# grade 100137.6
# condition 66146.3
#
# Prediction 959920.7

# %%
def prediction(v):
    print('Coefficients', np.round(model.coef_,1))
    print('Interception', round(model.intercept_, 1))
    print('')
    for i, col in enumerate(columns):
        print(col, round(model.coef_[i], 1))
    print('')
    prediction = model.predict([v])
    print('prediction', prediction.round(1)[0])
    print('')

from sklearn import linear_model

model = linear_model.LinearRegression()
columns = ['bedrooms', 'bathrooms','sqft_living', 'grade', 'condition']

train_vector = [3, 2, 2000, 6, 4]

df_zipcode = df[df['zipcode']==98002]
model.fit(df_zipcode[columns], df_zipcode['price'])
prediction(train_vector)    

df_zipcode = df[df['zipcode']==98039]
model.fit(df_zipcode[columns], df_zipcode['price'])
prediction(train_vector)
# Out:
# Coefficients [ 1777.6 19017.7    40.7 16782.  -1711.2]
# Interception 21176.7
#
# bedrooms 1777.6
# bathrooms 19017.7
# sqft_living 40.7
# grade 16782.0
# condition -1711.2
#
# prediction 239846.0
#
# Coefficients [ 17936.3 -26062.     591.8  84734.2 205766.3]
# Interception -1604338.7
#
# bedrooms 17936.3
# bathrooms -26062.0
# sqft_living 591.8
# grade 84734.2
# condition 205766.3
#
# prediction 912429.3
